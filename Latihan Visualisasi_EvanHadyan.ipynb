# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
data = pd.read_csv('covid_19_indonesia_time_series_all.csv')
data.head()
# Out:
#        Date Location ISO Code     Location  New Cases  New Deaths  \
# 0  3/1/2020             ID-JK  DKI Jakarta          2           0
# 1  3/2/2020             ID-JK  DKI Jakarta          2           0
# 2  3/2/2020               IDN    Indonesia          2           0
# 3  3/2/2020             ID-RI         Riau          1           0
# 4  3/3/2020             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            1             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  Latitude New Cases per Million  \
# 0               75  ... -6.204699                  0.18
# 1               75  ... -6.204699                  0.18
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         31822 non-null  object
#  1   Location ISO Code            31822 non-null  object
#  2   Location                     31822 non-null  object
#  3   New Cases                    31822 non-null  int64
#  4   New Deaths                   31822 non-null  int64
#  5   New Recovered                31822 non-null  int64
#  6   New Active Cases             31822 non-null  int64
#  7   Total Cases                  31822 non-null  int64
#  8   Total Deaths                 31822 non-null  int64
#  9   Total Recovered              31822 non-null  int64
#  10  Total Active Cases           31822 non-null  int64
#  11  Location Level               31822 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31822 entries, 0 to 31821
# Data columns (total 38 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         31822 non-null  datetime64[ns]
#  1   Location ISO Code            31822 non-null  object
#  2   Location                     31822 non-null  object
#  3   New Cases                    31822 non-null  int64
#  4   New Deaths                   31822 non-null  int64
#  5   New Recovered                31822 non-null  int64
#  6   New Active Cases             31822 non-null  int64
#  7   Total Cases                  31822 non-null  int64
#  8   Total Deaths                 31822 non-null  int64
#  9   Total Recovered              31822 non-null  int64
#  10  Total Active Cases           31822 non-null  int64
#  11  Location Level               31822 non-null  object
#  12  City or Regency              0 non-null      float64
# ...

# %%
data['Month-Year'] = data['Date'].dt.to_period('M')
data.head()
# Out:
#         Date Location ISO Code     Location  New Cases  New Deaths  \
# 0 2020-03-01             ID-JK  DKI Jakarta          2           0
# 1 2020-03-02             ID-JK  DKI Jakarta          2           0
# 2 2020-03-02               IDN    Indonesia          2           0
# 3 2020-03-02             ID-RI         Riau          1           0
# 4 2020-03-03             ID-JK  DKI Jakarta          2           0
#
#    New Recovered  New Active Cases  Total Cases  Total Deaths  \
# 0              0                 2           39            20
# 1              0                 2           41            20
# 2              0                 2            2             0
# 3              0                 1            1             0
# 4              0                 2           43            20
#
#    Total Recovered  ...  New Cases per Million Total Cases per Million  \
# 0               75  ...                   0.18                    3.60
# ...

# %%
data['Month-Year'].nunique()
# Out:
# 31

# %%
data['Month-Year'].value_counts()
# Out:
# 2021-05    1085
# 2021-03    1085
# 2022-05    1085
# 2022-03    1085
# 2022-01    1085
# 2021-12    1085
# 2021-10    1085
# 2021-08    1085
# 2021-07    1085
# 2022-08    1085
# 2022-07    1085
# 2020-08    1085
# 2020-12    1085
# 2020-05    1085
# 2020-10    1085
# 2020-07    1085
# 2021-01    1085
# 2021-11    1050
# 2022-06    1050
# 2022-04    1050
# 2020-06    1050
# 2021-06    1050
# 2020-09    1050
# 2021-09    1050
# 2020-11    1050
# 2021-04    1050
# 2020-04    1033
# 2022-02     980
# 2021-02     980
# 2022-09     524
# 2020-03     410
# Freq: M, Name: Month-Year, dtype: int64

# %%
grouped = data.groupby('Month-Year')[['Total Deaths', 'Total Recovered', 'Total Active Cases']].median().reset_index()
grouped #reset_index agar month-year berubah jadi fitur
# Out:
#    Month-Year  Total Deaths  Total Recovered  Total Active Cases
# 0     2020-03           1.0              3.0                -1.0
# 1     2020-04           3.0              6.0                14.0
# 2     2020-05           6.0             51.0                99.0
# 3     2020-06          11.0            182.5               135.5
# 4     2020-07          20.0            419.0               238.0
# 5     2020-08          36.0           1048.0               467.0
# 6     2020-09          71.0           1802.0               710.0
# 7     2020-10         123.0           3143.0               726.0
# 8     2020-11         170.5           4494.5               780.5
# 9     2020-12         238.0           5833.0              1257.0
# 10    2021-01         323.0           7643.0              1683.0
# 11    2021-02         382.0           9282.0              1762.5
# 12    2021-03         388.0          11947.0              1376.0
# ...

# %%
grouped['Month-Year'] = grouped['Month-Year'].astype('str')

# %%
plt.plot(grouped['Month-Year'], grouped['Total Deaths'])
plt.show()

# %%
plt.plot(grouped['Month-Year'], grouped['Total Deaths'])
plt.title('Deaths, Recovered, and Active Cases of Covid 2019')
plt.xlabel('Year-Month')
plt.ylabel('Victims')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.plot(grouped['Month-Year'], grouped['Total Deaths'])
plt.plot(grouped['Month-Year'], grouped['Total Recovered'])
plt.plot(grouped['Month-Year'], grouped['Total Active Cases'])
plt.title('Deaths, Recovered, and Active Cases of Covid 2019')
plt.xlabel('Year-Month')
plt.ylabel('Victims')
plt.xticks(rotation = 90)
plt.show()

# %%
plt.plot(grouped['Month-Year'], grouped['Total Deaths'],
         label = 'Total Deaths')
plt.plot(grouped['Month-Year'], grouped['Total Recovered'],
         label = 'Total Recovered')
plt.plot(grouped['Month-Year'], grouped['Total Active Cases'],
         label = 'Total Active Cases')
plt.title('Deaths, Recovered, and Active Cases of Covid 2019')
plt.xlabel('Year-Month')
plt.ylabel('Victims')
plt.xticks(rotation = 90)
plt.legend()
plt.show()

# %%
plt.plot(grouped['Month-Year'], grouped['Total Deaths'], '--k', 
         label = 'Total Deaths')
plt.plot(grouped['Month-Year'], grouped['Total Recovered'], 'g',
         label = 'Total Recovered')
plt.plot(grouped['Month-Year'], grouped['Total Active Cases'],
         label = 'Total Active Cases')
plt.title('Deaths, Recovered, and Active Cases of Covid 2019')
plt.xlabel('Year-Month')
plt.ylabel('Victims')
plt.xticks(rotation = 90)
plt.legend()
plt.show()

# %%
plt.plot(grouped['Month-Year'], grouped['Total Deaths'], linestyle = '--', color = 'k',
         label = 'Total Deaths')
plt.plot(grouped['Month-Year'], grouped['Total Recovered'], color = '#03C988',
         label = 'Total Recovered')
plt.plot(grouped['Month-Year'], grouped['Total Active Cases'],
         label = 'Total Active Cases')
plt.title('Deaths, Recovered, and Active Cases of Covid 2019')
plt.xlabel('Year-Month')
plt.ylabel('Victims')
plt.xticks(rotation = 90)
plt.legend()
plt.show()

# %%
plt.plot(grouped['Month-Year'], grouped['Total Deaths'], linestyle = '--', color = 'k',
         label = 'Total Deaths', linewidth = 2)
plt.plot(grouped['Month-Year'], grouped['Total Recovered'], color = '#03C988',
         label = 'Total Recovered', linewidth = 2)
plt.plot(grouped['Month-Year'], grouped['Total Active Cases'],
         label = 'Total Active Cases', linewidth = 3)
plt.title('Deaths, Recovered, and Active Cases of Covid 2019')
plt.xlabel('Year-Month')
plt.ylabel('Victims')
plt.xticks(rotation = 90)
plt.legend()
plt.show()

# %%
plt.plot(grouped['Month-Year'], grouped['Total Deaths'], linestyle = '--', color = 'k',
         label = 'Total Deaths', linewidth = 2)
plt.plot(grouped['Month-Year'], grouped['Total Recovered'], color = '#03C988',
         label = 'Total Recovered', linewidth = 2, linestyle='dotted')
plt.plot(grouped['Month-Year'], grouped['Total Active Cases'],
         label = 'Total Active Cases', linewidth = 3)
plt.title('Deaths, Recovered, and Active Cases of Covid 2019')
plt.xlabel('Year-Month')
plt.ylabel('Victims')
plt.xticks(rotation = 90)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#plot lip
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
#plt.xkcd() digunakan agar bisa jadi komik
plt.plot(grouped['Month-Year'], grouped['Total Deaths'], linestyle = '--', color = 'k',
         label = 'Total Deaths', linewidth = 3)
plt.plot(grouped['Month-Year'], grouped['Total Recovered'], color = '#F7A4A4',
         label = 'Total Recovered', linewidth = 2)
plt.plot(grouped['Month-Year'], grouped['Total Active Cases'],
         label = 'Total Active Cases', linewidth = 2.5)
plt.title('Deaths, Recovered, and Active Cases of Covid 2019')
plt.xlabel('Year-Month')
plt.ylabel('Victims')
plt.xticks(rotation = 90)
plt.legend()
plt.tight_layout()
plt.savefig('test.png')
plt.show()

# %%
#Menggabungkan 2 plot
fig, (ax1, ax2) = plt.subplots(ncols = 1, nrows = 2, figsize = (5,4))
ax1.plot(grouped['Month-Year'], grouped['Total Recovered'],
         label = 'Total Recovered')
ax1.set_title('Deaths, Recovered, and Active Cases of Covid 2019')
ax1.set_xlabel('Year-Month')
ax1.set_ylabel('Victims')
ax1.tick_params(rotation = 90)

ax2.plot(grouped['Month-Year'], grouped['Total Deaths'],
         label = 'Total Deaths')
ax2.plot(grouped['Month-Year'], grouped['Total Active Cases'],
         label = 'Total Active Cases')
ax2.set_title('Deaths, Recovered, and Active Cases of Covid 2019')
ax2.set_xlabel('Year-Month')
ax2.set_ylabel('Victims')
ax2.tick_params(rotation = 90)
#plt.legend()
plt.tight_layout()
plt.show()

# %%
#gabung 2 plot dengan 1 fig 2 ax
fig, (ax1, ax2) = plt.subplots(ncols = 1, nrows = 2, figsize = (6,5), sharex = True)
ax1.plot(grouped['Month-Year'], grouped['Total Recovered'],
         label = 'Total Recovered')
ax1.set_title('Deaths, Recovered, and Active Cases of Covid 2019')
ax1.set_xlabel('Year-Month')
ax1.set_ylabel('Victims')
ax1.tick_params(axis = 'x', rotation = 90)

ax2.plot(grouped['Month-Year'], grouped['Total Deaths'],
         label = 'Total Deaths')
ax2.plot(grouped['Month-Year'], grouped['Total Active Cases'],
         label = 'Total Active Cases')
ax2.set_xlabel('Year-Month')
ax2.set_ylabel('Victims')
ax2.tick_params(axis = 'x', rotation = 90)
plt.tight_layout()
plt.show()

# %%
#membuat 2 fig & 2 ax
fig1, ax1 = plt.subplots()
fig2, ax2 = plt.subplots()

ax1.plot(grouped['Month-Year'], grouped['Total Recovered'],
         label = 'Total Recovered', color='#B9F3FC', linestyle='--')
ax1.set_title('Recovered Cases of Covid 2019')
ax1.set_xlabel('Year-Month')
ax1.set_ylabel('Number Of Recovered')
ax1.tick_params(axis = 'x', rotation = 45)
ax1.legend()


ax2.plot(grouped['Month-Year'], grouped['Total Deaths'],
         label = 'Total Deaths', color='#301E67', linestyle='dotted')
ax2.plot(grouped['Month-Year'], grouped['Total Active Cases'],
         label = 'Total Active Cases', color='#FF8B13', linestyle='dashdot')
ax2.set_title('Active Covid and death')
ax2.set_xlabel('Year-Month')
ax2.set_ylabel('Death and Active Cases')
ax2.tick_params(axis = 'x', rotation = 45)
ax2.legend()


plt.tight_layout()

plt.show()

fig1.savefig('fig1.png', bbox_inches='tight') #bbox agar gambar tidak terpotong
fig2.savefig('fig2.png', bbox_inches='tight')
